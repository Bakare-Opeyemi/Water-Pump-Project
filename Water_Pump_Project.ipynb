# %% [markdown]
# ## Exploratory Data Analysis

# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Water_pump_dataset.csv',index_col=0)
data.head()
# Out:
#              timestamp  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_42  sensor_43  \
# 0   76.45975   13.41146   16.13136   15.56713  ...  31.770832   41.92708
# 1   76.45975   13.41146   16.13136   15.56713  ...  31.770832   41.92708
# 2   73.54598   13.32465   16.03733   15.61777  ...  31.770830   41.66666
# 3   76.98898   13.31742   16.24711   15.69734  ...  31.510420   40.88541
# 4   76.58897   13.35359   16.21094   15.69734  ...  31.510420   41.40625
#
# ...

# %%
data.shape
# Out:
# (166441, 52)

# %%
data.dtypes
# Out:
# timestamp     object
# sensor_00    float64
# sensor_01    float64
# sensor_02    float64
# sensor_03    float64
# sensor_04    float64
# sensor_05    float64
# sensor_06    float64
# sensor_07    float64
# sensor_08    float64
# sensor_09    float64
# sensor_10    float64
# sensor_11    float64
# sensor_12    float64
# sensor_13    float64
# sensor_14    float64
# sensor_16    float64
# sensor_17    float64
# sensor_18    float64
# sensor_19    float64
# sensor_20    float64
# sensor_21    float64
# sensor_22    float64
# sensor_23    float64
# sensor_24    float64
# sensor_25    float64
# sensor_26    float64
# sensor_27    float64
# sensor_28    float64
# sensor_29    float64
# sensor_30    float64
# sensor_31    float64
# sensor_32    float64
# sensor_33    float64
# sensor_34    float64
# sensor_35    float64
# sensor_36    float64
# sensor_37    float64
# sensor_38    float64
# sensor_39    float64
# sensor_40    float64
# sensor_41    float64
# sensor_42    float64
# ...

# %%
data.index = pd.to_datetime(data.timestamp)
data.drop('timestamp',axis=1,inplace=True)
data.head()
# Out:
#                      sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# timestamp
# 2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#                      sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# timestamp
# 2018-04-01 00:00:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:01:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:02:00   73.54598   13.32465   16.03733   15.61777   15.01013
# 2018-04-01 00:03:00   76.98898   13.31742   16.24711   15.69734   15.08247
# 2018-04-01 00:04:00   76.58897   13.35359   16.21094   15.69734   15.08247
#
# ...

# %%
data.tail()
# Out:
#                      sensor_00  sensor_01  sensor_02  sensor_03   sensor_04  \
# timestamp
# 2018-07-25 13:56:00   2.313889  45.833330   53.03819  43.923610   71.464119
# 2018-07-25 13:57:00   2.315856  45.833332   53.03819  43.923611    3.336227
# 2018-07-25 13:58:00   2.322743  45.833330   52.99479  43.923610    3.336227
# 2018-07-25 13:59:00   2.315856  45.789930   53.03819  43.880210    3.336227
# 2018-07-25 14:00:00   2.318808  45.833332   52.99479  43.880210  420.503448
#
#                      sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# timestamp
# 2018-07-25 13:56:00   73.00980   14.36632   16.21094   15.69734   15.12587
# 2018-07-25 13:57:00   72.47576   14.33015   16.16030   15.76968   15.16204
# 2018-07-25 13:58:00   70.48889   14.46036   16.16030   15.73351   15.01013
# 2018-07-25 13:59:00   68.74365   14.43866   16.07350   15.53096   15.05353
# 2018-07-25 14:00:00   72.52040   14.18547   16.24711   15.69734   15.05353
#
# ...

# %%
data.describe()
# Out:
#            sensor_00      sensor_01      sensor_02      sensor_03  \
# count  166441.000000  166441.000000  166441.000000  166441.000000
# mean        2.348569      47.016965      50.628361      43.337738
# std         0.447107       3.424241       4.139904       2.584527
# min         0.000000      22.439240      33.159720      31.640620
# 25%         2.404398      45.789930      50.130210      42.361110
# 50%         2.455556      47.612850      51.649300      43.793400
# 75%         2.497859      49.001740      52.951390      44.965275
# max         2.549016      55.772570      56.032990      48.220490
#
#            sensor_04      sensor_05      sensor_06      sensor_07  \
# count  166441.000000  166441.000000  166441.000000  166441.000000
# mean      577.716084      74.266212      13.097378      15.622506
# std       161.666372      19.456294       2.304404       2.447046
# min         2.798032       0.000000       0.014468       0.000000
# ...

# %%
data.columns
# Out:
# Index(['sensor_00', 'sensor_01', 'sensor_02', 'sensor_03', 'sensor_04',
#        'sensor_05', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09',
#        'sensor_10', 'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14',
#        'sensor_16', 'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20',
#        'sensor_21', 'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25',
#        'sensor_26', 'sensor_27', 'sensor_28', 'sensor_29', 'sensor_30',
#        'sensor_31', 'sensor_32', 'sensor_33', 'sensor_34', 'sensor_35',
#        'sensor_36', 'sensor_37', 'sensor_38', 'sensor_39', 'sensor_40',
#        'sensor_41', 'sensor_42', 'sensor_43', 'sensor_44', 'sensor_45',
#        'sensor_46', 'sensor_47', 'sensor_48', 'sensor_49', 'sensor_51', 'rul'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 166441 entries, 2018-04-01 00:00:00 to 2018-07-25 14:00:00
# Data columns (total 51 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   sensor_00  166441 non-null  float64
#  1   sensor_01  166441 non-null  float64
#  2   sensor_02  166441 non-null  float64
#  3   sensor_03  166441 non-null  float64
#  4   sensor_04  166441 non-null  float64
#  5   sensor_05  166441 non-null  float64
#  6   sensor_06  166441 non-null  float64
#  7   sensor_07  166441 non-null  float64
#  8   sensor_08  166441 non-null  float64
#  9   sensor_09  166441 non-null  float64
#  10  sensor_10  166441 non-null  float64
#  11  sensor_11  166441 non-null  float64
#  12  sensor_12  166441 non-null  float64
#  13  sensor_13  166441 non-null  float64
#  14  sensor_14  166441 non-null  float64
#  15  sensor_16  166441 non-null  float64
#  16  sensor_17  166441 non-null  float64
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
data.plot(figsize = (15,8))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
#Creating a function for plotting columns in the dataset
def plotColumn(columns,titles):
    axes= []
    for i in range(len(columns)):
        axes.append(columns[i].plot(figsize=(10,5)))
    for j in range(len(axes)):
        axes[j].set_title(titles[j])
    plt.show()

# %%
columns = [data[data.columns[:5]],data[data.columns[5:10]],data[data.columns[10:15]]]
titles = ['sensor00-sensor04','sensor05-sensor09','sensor10-sensor14']
plotColumn(columns,titles)

# %%
columns = [data[data.columns[15:20]],data[data.columns[20:25]],data[data.columns[25:30]]]
titles = ['sensor16-sensor20','sensor21-sensor25','sensor26-sensor30']
plotColumn(columns,titles)

# %%
columns = [data[data.columns[30:35]],data[data.columns[35:40]],data[data.columns[40:45]]]
titles = ['sensor31-sensor35','sensor36-sensor40','sensor41-sensor45']
plotColumn(columns,titles)

# %%
columns = [data[data.columns[45:48]],data[data.columns[48:51]]]
titles = ['sensor46-sensor48','sensor49-RUL']
plotColumn(columns,titles)

# %%
april_data = data[:'2018-04']
ax = april_data[['sensor_49','sensor_51','rul']].plot(figsize= (15,8))
ax.set_title('plot of sensors 49, 51 and the RUL in April')
# Out:
# Text(0.5, 1.0, 'plot of sensors 49, 51 and the RUL in April')

# %%
data[['sensor_02','sensor_03']].plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
data.head()
# Out:
#                      sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# timestamp
# 2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#                      sensor_05  sensor_06  sensor_07  sensor_08  sensor_09  \
# timestamp
# 2018-04-01 00:00:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:01:00   76.45975   13.41146   16.13136   15.56713   15.05353
# 2018-04-01 00:02:00   73.54598   13.32465   16.03733   15.61777   15.01013
# 2018-04-01 00:03:00   76.98898   13.31742   16.24711   15.69734   15.08247
# 2018-04-01 00:04:00   76.58897   13.35359   16.21094   15.69734   15.08247
#
# ...

# %% [markdown]
# ### INFERENCE
# <P> We can see from the plots of a number of combinations of sensor readings that the readings vary in an approximately same manner in magnitude</P>
# <p> To get deeper insights into the data, we will plot the percent changes of some sensor values in relation to the target variable </p>

# %%
changes= data.pct_change().dropna()
columns = [changes[changes.columns[:5]],changes[changes.columns[5:10]],changes[changes.columns[10:15]]]
titles = ['Changes in sensor00-sensor04 readings','Changes in sensor05-sensor09 readings','Changes in  sensor10-sensor14 readings']
plotColumn(columns,titles)

# %%
#Creating a function for plotting columns in the dataset
def plotColumn(columns,titles):
    axes= []
    for i in range(len(columns)):
        axes.append(columns[i].plot(figsize=(10,5)))
    for j in range(len(axes)):
        axes[j].set_title(titles[j])
        axes[j].axhspan(-1,1, color ='violet',alpha = 0.3)
    plt.show()

# %%
columns = [changes[['sensor_10', 'sensor_16', 'rul']],changes[['sensor_20','sensor_27','rul']],changes[['sensor_30','sensor_35','rul']]]
titles = ['Changes in sensor_10,15 and Remaining Useful Life','Changes in sensor_20,27 and Remaining Useful Life','Changes in  sensor30,35 and Remaining Useful Life']
plotColumn(columns,titles)

# %% [markdown]
# ### INFERENCE

# %% [markdown]
# <p>from the plots, we can see that the changes in sensor readings over a period of time is relatively small or near zero with very high spikes at random intervals</p>
# <p> Next we shall check the nature of the correlation of the sensor readings with the remaining useful life of the water pump

# %%
data[['sensor_00','rul']].corr()
# Out:
#            sensor_00       rul
# sensor_00   1.000000  0.059091
# rul         0.059091  1.000000

# %%
data[data.columns[0:10]].join(data[['rul']], how = 'left').corr()
# Out:
#            sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  sensor_05  \
# sensor_00   1.000000   0.239471   0.426486   0.274309   0.486366   0.625454
# sensor_01   0.239471   1.000000   0.770302   0.681935   0.708542   0.206339
# sensor_02   0.426486   0.770302   1.000000   0.847565   0.835124   0.282698
# sensor_03   0.274309   0.681935   0.847565   1.000000   0.701660   0.188851
# sensor_04   0.486366   0.708542   0.835124   0.701660   1.000000   0.408885
# sensor_05   0.625454   0.206339   0.282698   0.188851   0.408885   1.000000
# sensor_06   0.516891   0.374464   0.532540   0.421241   0.630469   0.653526
# sensor_07   0.367650   0.378638   0.481956   0.388334   0.531025   0.549897
# sensor_08   0.399368   0.356042   0.438223   0.355559   0.476681   0.476428
# sensor_09   0.329300   0.387895   0.481987   0.398889   0.489659   0.519179
# rul         0.059091   0.105406   0.123011   0.040416   0.015732  -0.136829
#
# ...

# %%
data[data.columns[10:20]].join(data[['rul']], how = 'left').corr()
# Out:
#            sensor_10  sensor_11  sensor_12  sensor_13  sensor_14  sensor_16  \
# sensor_10   1.000000   0.846136   0.795897   0.240840  -0.045833  -0.046343
# sensor_11   0.846136   1.000000   0.848347   0.373257  -0.115227  -0.111397
# sensor_12   0.795897   0.848347   1.000000   0.318885  -0.112382  -0.109815
# sensor_13   0.240840   0.373257   0.318885   1.000000   0.142596   0.137864
# sensor_14  -0.045833  -0.115227  -0.112382   0.142596   1.000000   0.989997
# sensor_16  -0.046343  -0.111397  -0.109815   0.137864   0.989997   1.000000
# sensor_17  -0.036971  -0.088472  -0.109631   0.117590   0.929446   0.952275
# sensor_18  -0.024684  -0.074393  -0.090072   0.109928   0.899909   0.925286
# sensor_19  -0.043298  -0.110966  -0.101491   0.137771   0.983077   0.979454
# sensor_20  -0.040594  -0.109457  -0.097162   0.139462   0.979897   0.976778
# rul         0.040089  -0.122571  -0.015098  -0.276943   0.097769   0.094736
#
# ...

# %%
data[data.columns[20:30]].join(data[['rul']], how = 'left').corr()
# Out:
#            sensor_21  sensor_22  sensor_23  sensor_24  sensor_25  sensor_26  \
# sensor_21   1.000000   0.984960   0.984563   0.985993   0.983162   0.966672
# sensor_22   0.984960   1.000000   0.986903   0.977462   0.985471   0.970751
# sensor_23   0.984563   0.986903   1.000000   0.973855   0.978485   0.975841
# sensor_24   0.985993   0.977462   0.973855   1.000000   0.970545   0.949723
# sensor_25   0.983162   0.985471   0.978485   0.970545   1.000000   0.978204
# sensor_26   0.966672   0.970751   0.975841   0.949723   0.978204   1.000000
# sensor_27   0.447063   0.408608   0.446704   0.443543   0.413793   0.445715
# sensor_28   0.910815   0.889642   0.897994   0.901145   0.888503   0.881570
# sensor_29   0.743897   0.700225   0.692000   0.749190   0.716354   0.657188
# sensor_30   0.842651   0.812994   0.840941   0.830312   0.819309   0.837582
# rul         0.093505   0.094671   0.039179   0.112879   0.088177   0.045198
#
# ...

# %%
data[data.columns[30:40]].join(data[['rul']], how = 'left').corr()
# Out:
#            sensor_31  sensor_32  sensor_33  sensor_34  sensor_35  sensor_36  \
# sensor_31   1.000000   0.891747   0.861720   0.513710   0.687279   0.486377
# sensor_32   0.891747   1.000000   0.886820   0.594139   0.744280   0.551971
# sensor_33   0.861720   0.886820   1.000000   0.488393   0.656598   0.460237
# sensor_34   0.513710   0.594139   0.488393   1.000000   0.883816   0.799353
# sensor_35   0.687279   0.744280   0.656598   0.883816   1.000000   0.736967
# sensor_36   0.486377   0.551971   0.460237   0.799353   0.736967   1.000000
# sensor_37  -0.106498  -0.186789  -0.017523  -0.471111  -0.356952  -0.379126
# sensor_38  -0.063259  -0.078362  -0.024407   0.001346  -0.066307  -0.027487
# sensor_39   0.026404   0.014855   0.049203   0.016091   0.015611   0.005157
# sensor_40  -0.040164  -0.028584  -0.006685   0.085282  -0.009020   0.030461
# rul         0.043659   0.082229   0.065709  -0.027323  -0.071178  -0.069812
#
# ...

# %%
data[data.columns[40:]].corr()
# Out:
#            sensor_41  sensor_42  sensor_43  sensor_44  sensor_45  sensor_46  \
# sensor_41   1.000000   0.707618   0.508905   0.263171   0.158758   0.197100
# sensor_42   0.707618   1.000000   0.787164   0.156127   0.200117   0.333911
# sensor_43   0.508905   0.787164   1.000000   0.228510   0.287463   0.535540
# sensor_44   0.263171   0.156127   0.228510   1.000000   0.380568   0.263475
# sensor_45   0.158758   0.200117   0.287463   0.380568   1.000000   0.693786
# sensor_46   0.197100   0.333911   0.535540   0.263475   0.693786   1.000000
# sensor_47   0.368650   0.178251   0.232719   0.603768   0.269322   0.319508
# sensor_48   0.012193  -0.008056   0.093804   0.315766   0.350678   0.259415
# sensor_49   0.197082   0.102682   0.137780   0.588828   0.371657   0.188437
# sensor_51  -0.144370  -0.132559  -0.150038  -0.042406  -0.049623  -0.070844
# rul         0.143912   0.099217   0.034813  -0.074899  -0.012358   0.029672
#
# ...

# %% [markdown]
# ### INFERENCE
# <P>We can see some highly correlating features which might be an indication of the existence of duplicates in the dataset and an underlying problem of multicollinearity in the dataset.</P>
# <ul>
#     <li> Sensors 01,02,03,04 are highly correlating</li>
#     <li> Sensors 10,11,12 are also highly correlating</li>
#     <li> Sensors 14,16,17,18,19,20 are highly correlating</li>
#     <li> Sensors 21,22,23,24,25,26,28,29,30 are highly correlating</li>
#     <li> Sensors 31,32,33,35 are highly correlating</li>
#     <li> Sensors 41,42,43 are highly correlating</li>
# </ul>
# <p> Next we check the dataset for duplicates and then plot monthly aggregates of the data to gain more insights into the nature of the features in the dataset</p>

# %%
#Checking duplicated rows in the data
data.duplicated().sum()
# Out:
# 0

# %%
data_month= data.index.month
data_by_month = data.groupby(data_month).mean()

# %%
data_by_month.head()
# Out:
#            sensor_00  sensor_01  sensor_02  sensor_03   sensor_04  sensor_05  \
# timestamp
# 4           2.362873  47.727551  50.611419  43.155838  570.748283  71.510252
# 5           2.332124  47.546331  52.327549  44.174138  611.372488  72.260892
# 6           2.379829  48.127868  50.645179  42.814349  584.112462  78.771097
# 7           2.313703  44.126672  48.485869  43.143720  535.973295  74.660660
#
#            sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_42  \
# timestamp                                              ...
# 4          12.418613  15.265200  14.873594  14.213001  ...  36.754653
# 5          13.186572  15.838535  15.069513  14.902981  ...  35.989145
# 6          13.354903  15.701041  15.047768  14.805806  ...  35.935732
# 7          13.498946  15.690285  15.039953  14.719857  ...  34.310831
#
#            sensor_43  sensor_44  sensor_45  sensor_46  sensor_47   sensor_48  \
# timestamp
# ...

# %%
#Plotting monthly aggregates of the readings from sensors 00,01 and 02
ax = data_by_month[data_by_month.columns[:4]].plot(figsize=(10,6), title = 'Monthly Aggregate of  sensor00, 01, 02 and 03 Data: CASE-STUDY A ')
plt.show()

# %%
#Plotting monthly aggregates of the readings from sensors 03,04 and 05
ax = data_by_month[data_by_month.columns[4:6]].plot(figsize=(10,6), title = 'Monthly Aggregate of  sensor 04 and 05 Data ')
plt.show()

# %%
#Plotting monthly aggregates of the readings from sensors 06,07 and 08
ax = data_by_month[data_by_month.columns[6:9]].plot(figsize=(10,6), title = 'Monthly Aggregate of  sensor06, 07 and 08 Data: CASE-STUDY B ')
plt.show()

# %%
#Creating a function for plotting aggregates of features in the dataset
def plotAggregates(columns,titles):
    axes= []
    for i in range(len(columns)):
        axes.append(columns[i].plot(figsize=(12,5)))
    for j in range(len(axes)):
        axes[j].set_title(titles[j])
    plt.show()

# %%
columns = [data_by_month[data_by_month.columns[9:12]],data_by_month[data_by_month.columns[12:15]],data_by_month[data_by_month.columns[15:18]]]
titles = ['Monthly Aggregate of  sensor09, 10 and 11 Data ','Monthly Aggregate of  sensor 12, 13 and 14 Data ','Monthly Aggregate of  sensor16, 17 and 18 Data: CASE-STUDY B1 ']
plotAggregates(columns,titles)

# %%
columns = [data_by_month[data_by_month.columns[18:21]],data_by_month[data_by_month.columns[21:25]],data_by_month[data_by_month.columns[25:28]]]
titles = ['Monthly Aggregate of  sensor19, 20 and 21 Data:CASE-STUDY B2 ','Monthly Aggregate of  sensor 22,23,24 and 25 Data:CASE-STUDY C ','Monthly Aggregate of  sensor 26,27 and 28 Data ']
plotAggregates(columns,titles)

# %%
columns = [data_by_month[data_by_month.columns[28:32]],data_by_month[data_by_month.columns[32:36]],data_by_month[data_by_month.columns[36:40]]]
titles = ['Monthly Aggregate of  sensor29, 30, 31 and 32 Data: CASE-STUDY C1','Monthly Aggregate of  sensor 33, 34, 35 and 36 Data ','Monthly Aggregate of  sensor 37,38,39 and 40 Data: CASE-STUDY D ']
plotAggregates(columns,titles)

# %%
columns = [data_by_month[data_by_month.columns[40:44]],data_by_month[data_by_month.columns[44:48]],data_by_month[data_by_month.columns[48:50]]]
titles = ['Monthly Aggregate of  sensor41, 42, 43 and 44 Data: CASE-STUDY E ','Monthly Aggregate of  sensor 45, 46, 47 and 48 Data ','Monthly Aggregate of  sensor 49 and 51 Data ']
plotAggregates(columns,titles)

# %%
plotAggregates([data['rul']],['Monthly Aggregate of the Remaining Useful life of The water Pump'])

# %% [markdown]
# ### INFERENCE
# <p>From the monthly aggregate plots of features in the dataset, the following patterns have been observed; </p>
# <ul>
#     <li>Most sensors record lower values in June or sometime between May and June</li>
#     <li>The plots also highlight the relationship between highly correlating sensors such as seen in CASE-STUDIES A,C,D and E. Here we can see that some plots are simply approximates of each other and it is very possible to predict one plot from the other based on this monthly trend.</li>
#     <li>We can also see that many sensors record their highest values in May and July. This is evident in CASE-STUDIES C1,B1,B2 and B </li>
# </ul>
# <p> Next we shall plot daily aggregates of the sensor readings in other to gain more insights into the dataset</p>

# %%
data_day = data.index.day
data_by_day = data.groupby(data_day).mean()
ax= data_by_day[['sensor_00','sensor_01','sensor_02', 'sensor_03']].plot(figsize=(15,8),title = 'Daily aggregate plot of sensors 01,02 and 03')
plt.show()

# %%
columns = [data_by_day[data_by_day.columns[4:7]],data_by_day[data_by_day.columns[7:11]],data_by_day[data_by_day.columns[11:16]]]
titles = ['Daily Aggregate plot of  sensor04,05 and 06','Daily Aggregate Plot of  sensor 07, 08,09 and 10','Daily Aggregate plot of  sensor 11,12,13,14, and 16 ']
plotAggregates(columns,titles)

# %%
columns = [data_by_day[data_by_day.columns[16:20]],data_by_day[data_by_day.columns[20:25]],data_by_day[data_by_day.columns[25:30]]]
titles = ['Daily Aggregate plot of  sensor17,18,19 and 20','Daily Aggregate Plot of  sensor 21, 22,23,24 and 25','Daily Aggregate plot of  sensor 26,27,28,29 and 30 ']
plotAggregates(columns,titles)

# %%
plotAggregates([data_by_day['sensor_18']],['Sensor_18 Daily Aggregate Plot'])

# %%
columns = [data_by_day[data_by_day.columns[30:36]],data_by_day[data_by_day.columns[36:41]],data_by_day[data_by_day.columns[41:46]]]
titles = ['Daily Aggregate plot of  sensor31,32,33,34,35 and 36','Daily Aggregate Plot of  sensor 37,38,39,40 and 41','Daily Aggregate plot of  sensor 42,43,44,45 and 46']
plotAggregates(columns,titles)

# %%
columns = [data_by_day[data_by_day.columns[46:48]],data_by_day[data_by_day.columns[48:]]]
titles = ['Daily Aggregate plot of  sensor47 and 48','Daily Aggregate Plot of  sensor 49, 51 and RUL of Water Pump']
plotAggregates(columns,titles)

# %% [markdown]
# ### INFERENCE
# <p> Here we see a more pronounced daily trend in the dataset. All sensor readings pretty much behave the same way when analysed from the daily stand point. We also observe that highest sensor values are usually recorded on the 20th of each month</p>
# <p> Next we shall observe the changes in the datset and explore how the sensor readings change accross time. This is in the hopes of uncovering more hidden trends in the dataset</p>

# %%
data_day = changes.index.month
data_by_day = changes.groupby(data_day).mean().fillna(method='ffill')
ax= data_by_day[['sensor_21','sensor_22','sensor_23','sensor_24', 'rul']].plot(figsize=(15,8),title = 'Daily aggregate plot of Changes in sensors 01,02 and 03')
plt.show()

# %%
data_by_day.describe()
# Out:
#        sensor_00  sensor_01     sensor_02  sensor_03  sensor_04  sensor_05  \
# count  31.000000  31.000000  3.100000e+01  31.000000  31.000000  31.000000
# mean    0.052894   0.000014  1.383759e-05   0.000009   0.007768   0.000327
# std     0.193918   0.000042  2.688119e-05   0.000021   0.024301   0.001329
# min    -0.000334  -0.000047 -1.720485e-05  -0.000041  -0.000430  -0.001431
# 25%     0.000005  -0.000004 -6.639207e-08  -0.000003   0.000069   0.000072
# 50%     0.000011   0.000009  5.567868e-06   0.000006   0.000084   0.000156
# 75%     0.000053   0.000025  1.449363e-05   0.000021   0.000193   0.000254
# max     0.836171   0.000182  1.183621e-04   0.000057   0.121696   0.005060
#
#        sensor_06  sensor_07  sensor_08  sensor_09  ...  sensor_42  sensor_43  \
# count  31.000000  31.000000  31.000000  31.000000  ...  31.000000  31.000000
# mean    0.019359   0.009787   0.031736   0.249144  ...   0.000036   0.000188
# ...

# %%
data.loc['2018'].describe()
# Out:
#            sensor_00      sensor_01      sensor_02      sensor_03  \
# count  166441.000000  166441.000000  166441.000000  166441.000000
# mean        2.348569      47.016965      50.628361      43.337738
# std         0.447107       3.424241       4.139904       2.584527
# min         0.000000      22.439240      33.159720      31.640620
# 25%         2.404398      45.789930      50.130210      42.361110
# 50%         2.455556      47.612850      51.649300      43.793400
# 75%         2.497859      49.001740      52.951390      44.965275
# max         2.549016      55.772570      56.032990      48.220490
#
#            sensor_04      sensor_05      sensor_06      sensor_07  \
# count  166441.000000  166441.000000  166441.000000  166441.000000
# mean      577.716084      74.266212      13.097378      15.622506
# std       161.666372      19.456294       2.304404       2.447046
# min         2.798032       0.000000       0.014468       0.000000
# ...
